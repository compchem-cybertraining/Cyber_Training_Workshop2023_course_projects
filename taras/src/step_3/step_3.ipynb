# %% [markdown]
# # Computing the nonadiabatic couplings in Kohn-Sham and excited states bases
#
# In this tutorial, we will start computing the nonadiabatic couplings (NACs) from the molecular orbital overlap files obtained in [step2](../../7_step2_cp2k/1_DFT). The NACs will be computed in Kohn-Sham states and also in both single-partcile (SP) and many-body (MB) excited state bases. We will plot the NAC map and distribution and plotting the average density of states, excitation analysis, energy vs time, and influence spectrum are brought in [this tutorial](../../../../11_program_specific_methods/3_cp2k_methods).
#
# ## Table of contents
# <a name="toc"></a>
# 1. [Importing needed libraries](#import)
# 2. [Overview of required files](#required_files)
# 3. [Computing NACs](#comp_nacs)     \
#    3.1. [Kohn-Sham basis](#KS)\
#    3.2. [Excited state basis](#excited_states)
# 4. [Plot results](#plot_res)\
#    4.1. [Energy vs time](#ene_time)\
#    4.2. [Average density of states](#ave_pdos)\
#    4.3. [NAC map](#nac_map)\
#    4.4. [NAC distribution](#nac_dist)\
#    4.5. [Influence spectrum](#inf_spec)
#
#
# ### A. Learning objectives
#
# * To be able to compute NACs in Kohn-Sham and excited state bases
# * To be able to plot the computed excited states energies vs time
# * To be able to plot the average partial density of states
# * To be able to plot the NAC maps and distributions
# * To be able to compute and plot the influence spectrum
#
# ### B. Use cases
#
# * [Computing NACs](#comp_nacs)
# * [Plot results](#plot_res)
#
# ### C. Functions
#
# - `libra_py`
#   - `data_stat`
#     - [`cmat_distrib`](#nac_dist)
#   - `influence_spectrum`
#     - [`recipe1`](#inf_spec)
#   - `workflows`
#     - `nbra`
#       - [`step3`](#comp_nacs)
#         - [`run_step3_ks_nacs_libint`](#KS)
#         - [`run_step3_sd_nacs_libint`](#excited_states)
#   - `units`
#     - `au2ev`

# %% [markdown]
# ## 1. Importing needed libraries <a name="import"></a>
# [Back to TOC](#toc)
#
# Import `glob`, `numpy`, `scipy.sparse`, `matplotlib.pyplot`, and `step3` module which is used to compute the NACs in Kohn-Sham basis using `run_step3_ks_nacs_libint` and in excited states basis using `run_step3_sd_nacs_libint`.

# %%
import os
import glob
import numpy as np
import scipy.sparse as sp
from libra_py import units, data_stat, influence_spectrum
import matplotlib.pyplot as plt
from liblibra_core import *
from libra_py.workflows.nbra import step3
import libra_py.packages.cp2k.methods as CP2K_methods
# Out:
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)

# %% [markdown]
# ## 2. Overview of the files <a name="required_files"></a>
#
#
# * `../step_2/res`
#
# The MO overlap files are needed and stored in this folder.
#
# * `../step_2/all_logfiles`
#
# All of the logfiles obtained from the electronic structure calculations of CP2K. These files will be needed to find the Kohn-Sham HOMO index and also extract the the TD-DFT data for each step.

# %% [markdown]
# ## 3. Computing NACs <a name="comp_nacs"></a>
# [Back to TOC](#toc)
#
# ### 3.1. Kohn-Sham basis <a name="KS"></a>
#
# The `libra_py.workflow.nbra.step3.run_step3_ks_nacs_libint(params)` computes the NACs between pairs of Kohn-Sham states using the molecular orbitals time-overlaps.
#
# With no spin-orbit couplings, two blocks of the matrix is zero. Since most of the elements of the overlap matrices are zero, we use the `scipy.sparse` library for storing and loading them.
#
# The paramters for this function are as follows:
#
# `params['lowest_orbital']`: The lowest orbital considered in the computation of the MO overlaps. This value is exactly the same
# as in the `run_template.py` file in step2.
#
# `params['highest_orbital']`: The highest orbital considered in the computation of the MO overlaps. This value is exactly the same
# as in the `run_template.py` file in step2.
#
# `params['num_occ_states']`: The number of occupied orbitals to be considered from HOMO to lower occupied states. This value is defined by user.
#
# `params['num_unocc_states']`: The number of unoccupied orbitals to be considered from LUMO to higher unoccupied states. This value is defined by user.
#
# The two values above are used to create an active space which then will be used to select the elements from the MO overlap and
# energy matrices.
#
# `params['use_multiprocessing']`: A boolean flag to use the multiprocessing library of Python or not.
#
# `params['nprocs']`: The number of processors to be used for the calculations. Libra will use this only if the `params['use_multiprocessing']`
# is set to `True`.
#
# `params['time_step']`: The time-step used in the calculations in `fs`.
#
# `params['es_software']`: The name of the software package used to compute the electronic structure calculations. This will be used to generate the HOMO
# index of that system so it can build the active space.
#
# `params['path_to_npz_files']`: The full path to the MO overlap files.
#
# `params['logfile_directory']`: The full path to the folder where all the log files are stored.
#
# `params['path_to_save_ks_Hvibs']`: The full path to the folder in which the NACs between the Konh-Sham states are stored.
#
# `params['start_time']`: The start time-step.
#
# `params['finish_time']`: The finish time-step.
#
#
# After setting all the above paramters, the calculations are run using `step3.run_step3_ks_nacs_libint(params)`.

# %%
import os
import glob
import numpy as np
import scipy.sparse as sp
from libra_py import units, data_stat, influence_spectrum
import matplotlib.pyplot as plt
from liblibra_core import *
from libra_py.workflows.nbra import step3
import libra_py.packages.cp2k.methods as CP2K_methods
params_ks = {
              'lowest_orbital': 166-20, 'highest_orbital': 167 + 20, 'num_occ_states': 4, 'num_unocc_states': 4,
              'use_multiprocessing': False, 'nprocs': 1, 'time_step': 1.0, 'es_software': 'cp2k',
              'path_to_npz_files': '/home/taras/1_example_TiO2/res',
              'logfile_directory': '/home/taras/1_example_TiO2/all_logfiles',
              'path_to_save_ks_Hvibs': os.getcwd()+'/res-ks-DFT',
              'start_time': 100, 'finish_time': 300,
            }

# For KS orbitals
step3.run_step3_ks_nacs_libint(params_ks)
# Out:
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# mkdir: cannot create directory ‘/home/taras/work/projects-dir/taras/src/step_3/res-ks-DFT’: File exists
# Computing orthonormalization of St matrices in step 100
# Done with step 100 . Elapsed time: 0.029041767120361328
# Computing orthonormalization of St matrices in step 101
# Done with step 101 . Elapsed time: 0.04324817657470703
# Computing orthonormalization of St matrices in step 102
# Done with step 102 . Elapsed time: 0.03960013389587402
# Computing orthonormalization of St matrices in step 103
# Done with step 103 . Elapsed time: 0.04609084129333496
# Computing orthonormalization of St matrices in step 104
# Done with step 104 . Elapsed time: 0.0455775260925293
# Computing orthonormalization of St matrices in step 105
# Done with step 105 . Elapsed time: 0.03991103172302246
# Computing orthonormalization of St matrices in step 106
# Done with step 106 . Elapsed time: 0.043680667877197266
# Computing orthonormalization of St matrices in step 107
# Done with step 107 . Elapsed time: 0.045523881912231445
# Computing orthonormalization of St matrices in step 108
# Done with step 108 . Elapsed time: 0.04177260398864746
# Computing orthonormalization of St matrices in step 109
# Done with step 109 . Elapsed time: 0.042615413665771484
# Computing orthonormalization of St matrices in step 110
# Done with step 110 . Elapsed time: 0.04098820686340332
# Computing orthonormalization of St matrices in step 111
# Done with step 111 . Elapsed time: 0.041323184967041016
# Computing orthonormalization of St matrices in step 112
# Done with step 112 . Elapsed time: 0.04406452178955078
# Computing orthonormalization of St matrices in step 113
# Done with step 113 . Elapsed time: 0.05011892318725586
# Computing orthonormalization of St matrices in step 114
# Done with step 114 . Elapsed time: 0.060378313064575195
# Computing orthonormalization of St matrices in step 115
# Done with step 115 . Elapsed time: 0.04800915718078613
# Computing orthonormalization of St matrices in step 116
# Done with step 116 . Elapsed time: 0.041034698486328125
# Computing orthonormalization of St matrices in step 117
# Done with step 117 . Elapsed time: 0.04087066650390625
# Computing orthonormalization of St matrices in step 118
# Done with step 118 . Elapsed time: 0.0409398078918457
# Computing orthonormalization of St matrices in step 119
# Done with step 119 . Elapsed time: 0.0442204475402832
# Computing orthonormalization of St matrices in step 120
# Done with step 120 . Elapsed time: 0.048017024993896484
# Computing orthonormalization of St matrices in step 121
# Done with step 121 . Elapsed time: 0.044524192810058594
# Computing orthonormalization of St matrices in step 122
# Done with step 122 . Elapsed time: 0.04890275001525879
# Computing orthonormalization of St matrices in step 123
# Done with step 123 . Elapsed time: 0.05248761177062988
# Computing orthonormalization of St matrices in step 124
# Done with step 124 . Elapsed time: 0.05207514762878418
# Computing orthonormalization of St matrices in step 125
# Done with step 125 . Elapsed time: 0.05394744873046875
# Computing orthonormalization of St matrices in step 126
# Done with step 126 . Elapsed time: 0.043744564056396484
# Computing orthonormalization of St matrices in step 127
# Done with step 127 . Elapsed time: 0.042023420333862305
# Computing orthonormalization of St matrices in step 128
# Done with step 128 . Elapsed time: 0.049608469009399414
# Computing orthonormalization of St matrices in step 129
# Done with step 129 . Elapsed time: 0.047918081283569336
# Computing orthonormalization of St matrices in step 130
# Done with step 130 . Elapsed time: 0.04391908645629883
# Computing orthonormalization of St matrices in step 131
# Done with step 131 . Elapsed time: 0.04181098937988281
# Computing orthonormalization of St matrices in step 132
# Done with step 132 . Elapsed time: 0.04499530792236328
# Computing orthonormalization of St matrices in step 133
# Done with step 133 . Elapsed time: 0.041671037673950195
# Computing orthonormalization of St matrices in step 134
# Done with step 134 . Elapsed time: 0.05629730224609375
# Computing orthonormalization of St matrices in step 135
# Done with step 135 . Elapsed time: 0.04535484313964844
# Computing orthonormalization of St matrices in step 136
# Done with step 136 . Elapsed time: 0.04521441459655762
# Computing orthonormalization of St matrices in step 137
# Done with step 137 . Elapsed time: 0.050629377365112305
# Computing orthonormalization of St matrices in step 138
# Done with step 138 . Elapsed time: 0.047937870025634766
# Computing orthonormalization of St matrices in step 139
# Done with step 139 . Elapsed time: 0.04671478271484375
# Computing orthonormalization of St matrices in step 140
# Done with step 140 . Elapsed time: 0.043123722076416016
# Computing orthonormalization of St matrices in step 141
# Done with step 141 . Elapsed time: 0.04943132400512695
# Computing orthonormalization of St matrices in step 142
# Done with step 142 . Elapsed time: 0.05545496940612793
# Computing orthonormalization of St matrices in step 143
# Done with step 143 . Elapsed time: 0.04653668403625488
# Computing orthonormalization of St matrices in step 144
# Done with step 144 . Elapsed time: 0.047884464263916016
# Computing orthonormalization of St matrices in step 145
# Done with step 145 . Elapsed time: 0.04580402374267578
# Computing orthonormalization of St matrices in step 146
# Done with step 146 . Elapsed time: 0.04748225212097168
# Computing orthonormalization of St matrices in step 147
# Done with step 147 . Elapsed time: 0.04659700393676758
# Computing orthonormalization of St matrices in step 148
# Done with step 148 . Elapsed time: 0.0395970344543457
# Computing orthonormalization of St matrices in step 149
# Done with step 149 . Elapsed time: 0.04082655906677246
# Computing orthonormalization of St matrices in step 150
# Done with step 150 . Elapsed time: 0.040872812271118164
# Computing orthonormalization of St matrices in step 151
# Done with step 151 . Elapsed time: 0.040848731994628906
# Computing orthonormalization of St matrices in step 152
# Done with step 152 . Elapsed time: 0.05299782752990723
# Computing orthonormalization of St matrices in step 153
# Done with step 153 . Elapsed time: 0.04467463493347168
# Computing orthonormalization of St matrices in step 154
# Done with step 154 . Elapsed time: 0.048371315002441406
# Computing orthonormalization of St matrices in step 155
# Done with step 155 . Elapsed time: 0.04983711242675781
# Computing orthonormalization of St matrices in step 156
# Done with step 156 . Elapsed time: 0.04596662521362305
# Computing orthonormalization of St matrices in step 157
# Done with step 157 . Elapsed time: 0.04994511604309082
# Computing orthonormalization of St matrices in step 158
# Done with step 158 . Elapsed time: 0.0431978702545166
# Computing orthonormalization of St matrices in step 159
# Done with step 159 . Elapsed time: 0.04323840141296387
# Computing orthonormalization of St matrices in step 160
# Done with step 160 . Elapsed time: 0.04347848892211914
# Computing orthonormalization of St matrices in step 161
# Done with step 161 . Elapsed time: 0.04202556610107422
# Computing orthonormalization of St matrices in step 162
# Done with step 162 . Elapsed time: 0.0559539794921875
# Computing orthonormalization of St matrices in step 163
# Done with step 163 . Elapsed time: 0.045539140701293945
# Computing orthonormalization of St matrices in step 164
# Done with step 164 . Elapsed time: 0.04659867286682129
# Computing orthonormalization of St matrices in step 165
# Done with step 165 . Elapsed time: 0.04805803298950195
# Computing orthonormalization of St matrices in step 166
# Done with step 166 . Elapsed time: 0.04300332069396973
# Computing orthonormalization of St matrices in step 167
# Done with step 167 . Elapsed time: 0.04801535606384277
# Computing orthonormalization of St matrices in step 168
# Done with step 168 . Elapsed time: 0.04228615760803223
# Computing orthonormalization of St matrices in step 169
# Done with step 169 . Elapsed time: 0.04234910011291504
# Computing orthonormalization of St matrices in step 170
# Done with step 170 . Elapsed time: 0.04921984672546387
# Computing orthonormalization of St matrices in step 171
# Done with step 171 . Elapsed time: 0.04950380325317383
# Computing orthonormalization of St matrices in step 172
# Done with step 172 . Elapsed time: 0.06470561027526855
# Computing orthonormalization of St matrices in step 173
# Done with step 173 . Elapsed time: 0.04820132255554199
# Computing orthonormalization of St matrices in step 174
# Done with step 174 . Elapsed time: 0.04147791862487793
# Computing orthonormalization of St matrices in step 175
# Done with step 175 . Elapsed time: 0.043125152587890625
# Computing orthonormalization of St matrices in step 176
# Done with step 176 . Elapsed time: 0.04130673408508301
# Computing orthonormalization of St matrices in step 177
# Done with step 177 . Elapsed time: 0.060765743255615234
# Computing orthonormalization of St matrices in step 178
# Done with step 178 . Elapsed time: 0.05794215202331543
# Computing orthonormalization of St matrices in step 179
# Done with step 179 . Elapsed time: 0.04590487480163574
# Computing orthonormalization of St matrices in step 180
# Done with step 180 . Elapsed time: 0.04717445373535156
# Computing orthonormalization of St matrices in step 181
# Done with step 181 . Elapsed time: 0.04254460334777832
# Computing orthonormalization of St matrices in step 182
# Done with step 182 . Elapsed time: 0.04222750663757324
# Computing orthonormalization of St matrices in step 183
# Done with step 183 . Elapsed time: 0.04212141036987305
# Computing orthonormalization of St matrices in step 184
# Done with step 184 . Elapsed time: 0.04200387001037598
# Computing orthonormalization of St matrices in step 185
# Done with step 185 . Elapsed time: 0.042764902114868164
# Computing orthonormalization of St matrices in step 186
# Done with step 186 . Elapsed time: 0.057991981506347656
# Computing orthonormalization of St matrices in step 187
# Done with step 187 . Elapsed time: 0.048142194747924805
# Computing orthonormalization of St matrices in step 188
# Done with step 188 . Elapsed time: 0.04506039619445801
# Computing orthonormalization of St matrices in step 189
# Done with step 189 . Elapsed time: 0.048264265060424805
# Computing orthonormalization of St matrices in step 190
# Done with step 190 . Elapsed time: 0.04854846000671387
# Computing orthonormalization of St matrices in step 191
# Done with step 191 . Elapsed time: 0.052458763122558594
# Computing orthonormalization of St matrices in step 192
# Done with step 192 . Elapsed time: 0.043094635009765625
# Computing orthonormalization of St matrices in step 193
# Done with step 193 . Elapsed time: 0.04213118553161621
# Computing orthonormalization of St matrices in step 194
# Done with step 194 . Elapsed time: 0.04117393493652344
# Computing orthonormalization of St matrices in step 195
# Done with step 195 . Elapsed time: 0.0493314266204834
# Computing orthonormalization of St matrices in step 196
# Done with step 196 . Elapsed time: 0.061737060546875
# Computing orthonormalization of St matrices in step 197
# Done with step 197 . Elapsed time: 0.04662013053894043
# Computing orthonormalization of St matrices in step 198
# Done with step 198 . Elapsed time: 0.04503011703491211
# Computing orthonormalization of St matrices in step 199
# Done with step 199 . Elapsed time: 0.04481792449951172
# Computing orthonormalization of St matrices in step 200
# Done with step 200 . Elapsed time: 0.045247554779052734
# Computing orthonormalization of St matrices in step 201
# Done with step 201 . Elapsed time: 0.048692941665649414
# Computing orthonormalization of St matrices in step 202
# Done with step 202 . Elapsed time: 0.04219174385070801
# Computing orthonormalization of St matrices in step 203
# Done with step 203 . Elapsed time: 0.0422971248626709
# Computing orthonormalization of St matrices in step 204
# Done with step 204 . Elapsed time: 0.041463613510131836
# Computing orthonormalization of St matrices in step 205
# Done with step 205 . Elapsed time: 0.04182839393615723
# Computing orthonormalization of St matrices in step 206
# Done with step 206 . Elapsed time: 0.05228543281555176
# Computing orthonormalization of St matrices in step 207
# Done with step 207 . Elapsed time: 0.04374814033508301
# Computing orthonormalization of St matrices in step 208
# Done with step 208 . Elapsed time: 0.04462718963623047
# Computing orthonormalization of St matrices in step 209
# Done with step 209 . Elapsed time: 0.04679369926452637
# Computing orthonormalization of St matrices in step 210
# Done with step 210 . Elapsed time: 0.04895758628845215
# Computing orthonormalization of St matrices in step 211
# Done with step 211 . Elapsed time: 0.048484086990356445
# Computing orthonormalization of St matrices in step 212
# Done with step 212 . Elapsed time: 0.04707455635070801
# Computing orthonormalization of St matrices in step 213
# Done with step 213 . Elapsed time: 0.04810190200805664
# Computing orthonormalization of St matrices in step 214
# Done with step 214 . Elapsed time: 0.04899001121520996
# Computing orthonormalization of St matrices in step 215
# Done with step 215 . Elapsed time: 0.04857444763183594
# Computing orthonormalization of St matrices in step 216
# Done with step 216 . Elapsed time: 0.043730974197387695
# Computing orthonormalization of St matrices in step 217
# Done with step 217 . Elapsed time: 0.04166078567504883
# Computing orthonormalization of St matrices in step 218
# Done with step 218 . Elapsed time: 0.041646480560302734
# Computing orthonormalization of St matrices in step 219
# Done with step 219 . Elapsed time: 0.041707754135131836
# Computing orthonormalization of St matrices in step 220
# Done with step 220 . Elapsed time: 0.051903486251831055
# Computing orthonormalization of St matrices in step 221
# Done with step 221 . Elapsed time: 0.043242692947387695
# Computing orthonormalization of St matrices in step 222
# Done with step 222 . Elapsed time: 0.041834354400634766
# Computing orthonormalization of St matrices in step 223
# Done with step 223 . Elapsed time: 0.04191422462463379
# Computing orthonormalization of St matrices in step 224
# Done with step 224 . Elapsed time: 0.04157257080078125
# Computing orthonormalization of St matrices in step 225
# Done with step 225 . Elapsed time: 0.05122709274291992
# Computing orthonormalization of St matrices in step 226
# Done with step 226 . Elapsed time: 0.041622161865234375
# Computing orthonormalization of St matrices in step 227
# Done with step 227 . Elapsed time: 0.04208493232727051
# Computing orthonormalization of St matrices in step 228
# Done with step 228 . Elapsed time: 0.04167795181274414
# Computing orthonormalization of St matrices in step 229
# Done with step 229 . Elapsed time: 0.0416867733001709
# Computing orthonormalization of St matrices in step 230
# Done with step 230 . Elapsed time: 0.05235099792480469
# Computing orthonormalization of St matrices in step 231
# Done with step 231 . Elapsed time: 0.04226827621459961
# Computing orthonormalization of St matrices in step 232
# Done with step 232 . Elapsed time: 0.041423797607421875
# Computing orthonormalization of St matrices in step 233
# Done with step 233 . Elapsed time: 0.041492462158203125
# Computing orthonormalization of St matrices in step 234
# Done with step 234 . Elapsed time: 0.04179048538208008
# Computing orthonormalization of St matrices in step 235
# Done with step 235 . Elapsed time: 0.053699493408203125
# Computing orthonormalization of St matrices in step 236
# Done with step 236 . Elapsed time: 0.04181313514709473
# Computing orthonormalization of St matrices in step 237
# Done with step 237 . Elapsed time: 0.04147505760192871
# Computing orthonormalization of St matrices in step 238
# Done with step 238 . Elapsed time: 0.04157590866088867
# Computing orthonormalization of St matrices in step 239
# Done with step 239 . Elapsed time: 0.041944265365600586
# Computing orthonormalization of St matrices in step 240
# Done with step 240 . Elapsed time: 0.05446767807006836
# Computing orthonormalization of St matrices in step 241
# Done with step 241 . Elapsed time: 0.04193115234375
# Computing orthonormalization of St matrices in step 242
# Done with step 242 . Elapsed time: 0.041808366775512695
# Computing orthonormalization of St matrices in step 243
# Done with step 243 . Elapsed time: 0.04379916191101074
# Computing orthonormalization of St matrices in step 244
# Done with step 244 . Elapsed time: 0.04210853576660156
# Computing orthonormalization of St matrices in step 245
# Done with step 245 . Elapsed time: 0.05058479309082031
# Computing orthonormalization of St matrices in step 246
# Done with step 246 . Elapsed time: 0.04189753532409668
# Computing orthonormalization of St matrices in step 247
# Done with step 247 . Elapsed time: 0.0421597957611084
# Computing orthonormalization of St matrices in step 248
# Done with step 248 . Elapsed time: 0.04184222221374512
# Computing orthonormalization of St matrices in step 249
# Done with step 249 . Elapsed time: 0.04167819023132324
# Computing orthonormalization of St matrices in step 250
# Done with step 250 . Elapsed time: 0.05355262756347656
# Computing orthonormalization of St matrices in step 251
# Done with step 251 . Elapsed time: 0.041951656341552734
# Computing orthonormalization of St matrices in step 252
# Done with step 252 . Elapsed time: 0.041611671447753906
# Computing orthonormalization of St matrices in step 253
# Done with step 253 . Elapsed time: 0.0414276123046875
# Computing orthonormalization of St matrices in step 254
# Done with step 254 . Elapsed time: 0.0418095588684082
# Computing orthonormalization of St matrices in step 255
# Done with step 255 . Elapsed time: 0.05724477767944336
# Computing orthonormalization of St matrices in step 256
# Done with step 256 . Elapsed time: 0.04195809364318848
# Computing orthonormalization of St matrices in step 257
# Done with step 257 . Elapsed time: 0.041191816329956055
# Computing orthonormalization of St matrices in step 258
# Done with step 258 . Elapsed time: 0.04195666313171387
# Computing orthonormalization of St matrices in step 259
# Done with step 259 . Elapsed time: 0.04844403266906738
# Computing orthonormalization of St matrices in step 260
# Done with step 260 . Elapsed time: 0.04961538314819336
# Computing orthonormalization of St matrices in step 261
# Done with step 261 . Elapsed time: 0.042018890380859375
# Computing orthonormalization of St matrices in step 262
# Done with step 262 . Elapsed time: 0.04214787483215332
# Computing orthonormalization of St matrices in step 263
# Done with step 263 . Elapsed time: 0.041848182678222656
# Computing orthonormalization of St matrices in step 264
# Done with step 264 . Elapsed time: 0.041820526123046875
# Computing orthonormalization of St matrices in step 265
# Done with step 265 . Elapsed time: 0.05835127830505371
# Computing orthonormalization of St matrices in step 266
# Done with step 266 . Elapsed time: 0.053044795989990234
# Computing orthonormalization of St matrices in step 267
# Done with step 267 . Elapsed time: 0.04570341110229492
# Computing orthonormalization of St matrices in step 268
# Done with step 268 . Elapsed time: 0.04842853546142578
# Computing orthonormalization of St matrices in step 269
# Done with step 269 . Elapsed time: 0.04339146614074707
# Computing orthonormalization of St matrices in step 270
# Done with step 270 . Elapsed time: 0.05029892921447754
# Computing orthonormalization of St matrices in step 271
# Done with step 271 . Elapsed time: 0.04293942451477051
# Computing orthonormalization of St matrices in step 272
# Done with step 272 . Elapsed time: 0.042075395584106445
# Computing orthonormalization of St matrices in step 273
# Done with step 273 . Elapsed time: 0.04261207580566406
# Computing orthonormalization of St matrices in step 274
# Done with step 274 . Elapsed time: 0.050086021423339844
# Computing orthonormalization of St matrices in step 275
# Done with step 275 . Elapsed time: 0.0504450798034668
# Computing orthonormalization of St matrices in step 276
# Done with step 276 . Elapsed time: 0.04535675048828125
# Computing orthonormalization of St matrices in step 277
# Done with step 277 . Elapsed time: 0.0443575382232666
# Computing orthonormalization of St matrices in step 278
# Done with step 278 . Elapsed time: 0.04185914993286133
# Computing orthonormalization of St matrices in step 279
# Done with step 279 . Elapsed time: 0.0420224666595459
# Computing orthonormalization of St matrices in step 280
# Done with step 280 . Elapsed time: 0.04832768440246582
# Computing orthonormalization of St matrices in step 281
# Done with step 281 . Elapsed time: 0.04603838920593262
# Computing orthonormalization of St matrices in step 282
# Done with step 282 . Elapsed time: 0.047634124755859375
# Computing orthonormalization of St matrices in step 283
# Done with step 283 . Elapsed time: 0.04645800590515137
# Computing orthonormalization of St matrices in step 284
# Done with step 284 . Elapsed time: 0.04668378829956055
# Computing orthonormalization of St matrices in step 285
# Done with step 285 . Elapsed time: 0.0478663444519043
# Computing orthonormalization of St matrices in step 286
# Done with step 286 . Elapsed time: 0.04206347465515137
# Computing orthonormalization of St matrices in step 287
# Done with step 287 . Elapsed time: 0.04228854179382324
# Computing orthonormalization of St matrices in step 288
# Done with step 288 . Elapsed time: 0.041578054428100586
# Computing orthonormalization of St matrices in step 289
# Done with step 289 . Elapsed time: 0.04219937324523926
# Computing orthonormalization of St matrices in step 290
# Done with step 290 . Elapsed time: 0.052747249603271484
# Computing orthonormalization of St matrices in step 291
# Done with step 291 . Elapsed time: 0.04485964775085449
# Computing orthonormalization of St matrices in step 292
# Done with step 292 . Elapsed time: 0.04686284065246582
# Computing orthonormalization of St matrices in step 293
# Done with step 293 . Elapsed time: 0.04338264465332031
# Computing orthonormalization of St matrices in step 294
# Done with step 294 . Elapsed time: 0.04361534118652344
# Computing orthonormalization of St matrices in step 295
# Done with step 295 . Elapsed time: 0.0492246150970459
# Computing orthonormalization of St matrices in step 296
# Done with step 296 . Elapsed time: 0.044931888580322266
# Computing orthonormalization of St matrices in step 297
# Done with step 297 . Elapsed time: 0.0672307014465332
# Computing orthonormalization of St matrices in step 298
# Done with step 298 . Elapsed time: 0.05428266525268555
# Computing orthonormalization of St matrices in step 299
# Done with step 299 . Elapsed time: 0.05708146095275879
# Done with orthonormalization step. Elapsed time: 9.517902612686157
# Done with phase correction. Elapsed time: 10.351954936981201

# %% [markdown]
# ### 3.2. Excited state basis <a name="excited_states"></a>
# [Back to TOC](#toc)
#
# Below, we will be using `step3.run_step3_sd_nacs_libint` function to compute the time-overlaps and nonadiabatic couplings between excited states basis. This can be done either in the many-body or single-particle basis. A schematic of the workflow for selecting new active space is shown below:
#
#
# Some parameters are common with the ones used to run `step3.run_step3_ks_nacs_libint(params)` above.
#
# Other parameters needed to run the `step3.run_step3_sd_nacs_libint(params)` function are as follows:
#
# `params['isUKS']`: A boolean flag for unrestricted spin calculations.
#
# `params['is_many_body']`: If set to `True`, the NACs will be computed between pairs of many-body (TD-DFT) states. Also, the NACs between single-particle
# SDs obtained from the TD-DFT results will be computed as well. Otherwise, only single-particle NACs will be computed only for the SDs obtained from
# `num_occ_states` and `num_unocc_states`. This will be used for xTB calculations in which no TD-DFT was performed.
#
# `params['number_of_states']`: The number of TD-DFT states to consider. This value should not exceed the number of requested TD-DFT states in the CP2K
# calculations.
#
# `params['tolerance']`: A lower bound for selection of the excitation with configuration interaction coefficients higher than this value.
#
# `params['verbosity']`: An integer value showing the printing level. The default is set to 0. Higher values will print more data on the terminal.
#
# `params['sorting_type']`: After defining the SDs, Libra will sort them either based on `'energy'` or `'identity'`.
#
#
# The NACs can also be computed between excited states. These include the single-particle and many-body bases which the latter is obtained from the
# TD-DFT calculations. First, we need to compute the overlap between excited state Slater-determinants (SDs) then they will be used to compute the NACs
# between them. For many-body states, the configuration interaction coefficietns will be used. We will consider both single-particle
# and many-body for DFT calculations but only single-particle for xTB.
#
# There are different ways of defining the excited states SDs (the single-particle excited state basis). The first is through
# defining the `num_occ_states` and `num_unocc_states` in which Libra
# will start making the SDs from all of the occupied states (starting from `HOMO-num_occ_states+1`) to all of the unoccupied states (ends
# to `LUMO+num_unocc_states-1`). Also, if the unrestricted spin calculation flag is set to `True`, the SDs will be made for both alpha and beta spin channels.
#
# For example, if you want to build the electron-only excitation basis, you need to set `params['num_occ_states'] = 1` and set `params['num_unocc_states']`
# to a value less than the number of unoccupied orbitals that was considered in the computation of overlaps. This will generate all the electron-only
# excitation from HOMO to unoccupied states.
#
# If the TD-DFT calculations has been done, then Libra will go over all log files and
# generate all the SDs used for all the steps and therefore the definition of these SDs is automatic and Libra will replace the `num_occ_states` and
# `num_unocc_states` itself based on the SDs that were generated from the TD-DFT log files.

# %%
import os
import glob
import numpy as np
import scipy.sparse as sp
from libra_py import units, data_stat, influence_spectrum
import matplotlib.pyplot as plt
from liblibra_core import *
from libra_py.workflows.nbra import step3
import libra_py.packages.cp2k.methods as CP2K_methods
params_mb_sd = {
          'lowest_orbital': 166-20, 'highest_orbital': 167+20, 'num_occ_states': 4, 'num_unocc_states': 3,
          'isUKS': 1, 'number_of_states': 0, 'tolerance': 0.01, 'verbosity': 0, 'use_multiprocessing': False, 'nprocs': 1,
          'is_many_body': 0, 'time_step': 1.0, 'es_software': 'cp2k',
          'path_to_npz_files': '/home/taras/1_example_TiO2/res',
          'logfile_directory': '/home/taras/1_example_TiO2/all_logfiles',
          'path_to_save_sd_Hvibs': os.getcwd()+'/res-mb-sd-DFT',
          'outdir': os.getcwd()+'/res-mb-sd-DFT', 'start_time': 100, 'finish_time': 300, 'sorting_type': 'identity',
          'num_occ_alpha': 4,
          'num_occ_beta': 3,
          'num_unocc_alpha': 4,
          'num_unocc_beta': 5
         }

step3.run_step3_sd_nacs_libint(params_mb_sd)
# Out:
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /home/taras/work/libra-env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# mkdir: cannot create directory ‘/home/taras/work/projects-dir/taras/src/step_3/res-mb-sd-DFT’: File exists
# 0 : [[1, 5], 'alp']
# 1 : [[1, 6], 'alp']
# 2 : [[1, 7], 'alp']
# 3 : [[1, 8], 'alp']
# 4 : [[2, 5], 'alp']
# 5 : [[2, 6], 'alp']
# 6 : [[2, 7], 'alp']
# 7 : [[2, 8], 'alp']
# 8 : [[3, 5], 'alp']
# 9 : [[3, 6], 'alp']
# 10 : [[3, 7], 'alp']
# 11 : [[3, 8], 'alp']
# 12 : [[4, 5], 'alp']
# 13 : [[4, 6], 'alp']
# 14 : [[4, 7], 'alp']
# 15 : [[4, 8], 'alp']
# 16 : [[1, 4], 'bet']
# 17 : [[1, 5], 'bet']
# 18 : [[1, 6], 'bet']
# 19 : [[1, 7], 'bet']
# 20 : [[1, 8], 'bet']
# 21 : [[2, 4], 'bet']
# 22 : [[2, 5], 'bet']
# 23 : [[2, 6], 'bet']
# 24 : [[2, 7], 'bet']
# 25 : [[2, 8], 'bet']
# 26 : [[3, 4], 'bet']
# 27 : [[3, 5], 'bet']
# 28 : [[3, 6], 'bet']
# 29 : [[3, 7], 'bet']
# 30 : [[3, 8], 'bet']
# 0 : [1, -1, 2, -2, 3, -3, 4]
# 1 : [5, -1, 2, -2, 3, -3, 4]
# 2 : [6, -1, 2, -2, 3, -3, 4]
# 3 : [7, -1, 2, -2, 3, -3, 4]
# 4 : [8, -1, 2, -2, 3, -3, 4]
# 5 : [1, -1, 5, -2, 3, -3, 4]
# 6 : [1, -1, 6, -2, 3, -3, 4]
# 7 : [1, -1, 7, -2, 3, -3, 4]
# 8 : [1, -1, 8, -2, 3, -3, 4]
# 9 : [1, -1, 2, -2, 5, -3, 4]
# 10 : [1, -1, 2, -2, 6, -3, 4]
# 11 : [1, -1, 2, -2, 7, -3, 4]
# 12 : [1, -1, 2, -2, 8, -3, 4]
# 13 : [1, -1, 2, -2, 3, -3, 5]
# 14 : [1, -1, 2, -2, 3, -3, 6]
# 15 : [1, -1, 2, -2, 3, -3, 7]
# 16 : [1, -1, 2, -2, 3, -3, 8]
# 17 : [1, -4, 2, -2, 3, -3, 4]
# 18 : [1, -5, 2, -2, 3, -3, 4]
# 19 : [1, -6, 2, -2, 3, -3, 4]
# 20 : [1, -7, 2, -2, 3, -3, 4]
# 21 : [1, -8, 2, -2, 3, -3, 4]
# 22 : [1, -1, 2, -4, 3, -3, 4]
# 23 : [1, -1, 2, -5, 3, -3, 4]
# 24 : [1, -1, 2, -6, 3, -3, 4]
# 25 : [1, -1, 2, -7, 3, -3, 4]
# 26 : [1, -1, 2, -8, 3, -3, 4]
# 27 : [1, -1, 2, -2, 3, -4, 4]
# 28 : [1, -1, 2, -2, 3, -5, 4]
# 29 : [1, -1, 2, -2, 3, -6, 4]
# 30 : [1, -1, 2, -2, 3, -7, 4]
# 31 : [1, -1, 2, -2, 3, -8, 4]
# ks_homo_index 4
# ks_orbital_indicies range(1, 43)
# Sorting and computing the SDs energies...
# Done with sorting and computing the SDs energies. Elapsed time: 0.8479213714599609
# Computing the SD overlaps for step 0
# Done with computing the SD overlap of step 0. Elapsed time 0.028060436248779297
# Computing the SD overlaps for step 1
# Done with computing the SD overlap of step 1. Elapsed time 0.0286099910736084
# Computing the SD overlaps for step 2
# Done with computing the SD overlap of step 2. Elapsed time 0.025206327438354492
# Computing the SD overlaps for step 3
# Done with computing the SD overlap of step 3. Elapsed time 0.02641463279724121
# Computing the SD overlaps for step 4
# Done with computing the SD overlap of step 4. Elapsed time 0.02710580825805664
# Computing the SD overlaps for step 5
# Done with computing the SD overlap of step 5. Elapsed time 0.02685832977294922
# Computing the SD overlaps for step 6
# Done with computing the SD overlap of step 6. Elapsed time 0.02759408950805664
# Computing the SD overlaps for step 7
# Done with computing the SD overlap of step 7. Elapsed time 0.02686929702758789
# Computing the SD overlaps for step 8
# Done with computing the SD overlap of step 8. Elapsed time 0.027248620986938477
# Computing the SD overlaps for step 9
# Done with computing the SD overlap of step 9. Elapsed time 0.02916097640991211
# Computing the SD overlaps for step 10
# Done with computing the SD overlap of step 10. Elapsed time 0.029040813446044922
# Computing the SD overlaps for step 11
# Done with computing the SD overlap of step 11. Elapsed time 0.030669689178466797
# Computing the SD overlaps for step 12
# Done with computing the SD overlap of step 12. Elapsed time 0.03602957725524902
# Computing the SD overlaps for step 13
# Done with computing the SD overlap of step 13. Elapsed time 0.03346538543701172
# Computing the SD overlaps for step 14
# Done with computing the SD overlap of step 14. Elapsed time 0.029961824417114258
# Computing the SD overlaps for step 15
# Done with computing the SD overlap of step 15. Elapsed time 0.03129005432128906
# Computing the SD overlaps for step 16
# Done with computing the SD overlap of step 16. Elapsed time 0.029776811599731445
# Computing the SD overlaps for step 17
# Done with computing the SD overlap of step 17. Elapsed time 0.032267093658447266
# Computing the SD overlaps for step 18
# Done with computing the SD overlap of step 18. Elapsed time 0.032163143157958984
# Computing the SD overlaps for step 19
# Done with computing the SD overlap of step 19. Elapsed time 0.029739856719970703
# Computing the SD overlaps for step 20
# Done with computing the SD overlap of step 20. Elapsed time 0.03138017654418945
# Computing the SD overlaps for step 21
# Done with computing the SD overlap of step 21. Elapsed time 0.036224365234375
# Computing the SD overlaps for step 22
# Done with computing the SD overlap of step 22. Elapsed time 0.03042769432067871
# Computing the SD overlaps for step 23
# Done with computing the SD overlap of step 23. Elapsed time 0.029651165008544922
# Computing the SD overlaps for step 24
# Done with computing the SD overlap of step 24. Elapsed time 0.02991938591003418
# Computing the SD overlaps for step 25
# Done with computing the SD overlap of step 25. Elapsed time 0.028399229049682617
# Computing the SD overlaps for step 26
# Done with computing the SD overlap of step 26. Elapsed time 0.029701709747314453
# Computing the SD overlaps for step 27
# Done with computing the SD overlap of step 27. Elapsed time 0.029073238372802734
# Computing the SD overlaps for step 28
# Done with computing the SD overlap of step 28. Elapsed time 0.030071258544921875
# Computing the SD overlaps for step 29
# Done with computing the SD overlap of step 29. Elapsed time 0.029810428619384766
# Computing the SD overlaps for step 30
# Done with computing the SD overlap of step 30. Elapsed time 0.028074979782104492
# Computing the SD overlaps for step 31
# Done with computing the SD overlap of step 31. Elapsed time 0.028314590454101562
# Computing the SD overlaps for step 32
# Done with computing the SD overlap of step 32. Elapsed time 0.028439044952392578
# Computing the SD overlaps for step 33
# Done with computing the SD overlap of step 33. Elapsed time 0.031183242797851562
# Computing the SD overlaps for step 34
# Done with computing the SD overlap of step 34. Elapsed time 0.0291748046875
# Computing the SD overlaps for step 35
# Done with computing the SD overlap of step 35. Elapsed time 0.028923511505126953
# Computing the SD overlaps for step 36
# Done with computing the SD overlap of step 36. Elapsed time 0.028209686279296875
# Computing the SD overlaps for step 37
# Done with computing the SD overlap of step 37. Elapsed time 0.02893209457397461
# Computing the SD overlaps for step 38
# Done with computing the SD overlap of step 38. Elapsed time 0.029968976974487305
# Computing the SD overlaps for step 39
# Done with computing the SD overlap of step 39. Elapsed time 0.0297393798828125
# Computing the SD overlaps for step 40
# Done with computing the SD overlap of step 40. Elapsed time 0.030031919479370117
# Computing the SD overlaps for step 41
# Done with computing the SD overlap of step 41. Elapsed time 0.028424739837646484
# Computing the SD overlaps for step 42
# Done with computing the SD overlap of step 42. Elapsed time 0.027096986770629883
# Computing the SD overlaps for step 43
# Done with computing the SD overlap of step 43. Elapsed time 0.027308940887451172
# Computing the SD overlaps for step 44
# Done with computing the SD overlap of step 44. Elapsed time 0.027811527252197266
# Computing the SD overlaps for step 45
# Done with computing the SD overlap of step 45. Elapsed time 0.027551889419555664
# Computing the SD overlaps for step 46
# Done with computing the SD overlap of step 46. Elapsed time 0.02837824821472168
# Computing the SD overlaps for step 47
# Done with computing the SD overlap of step 47. Elapsed time 0.027968645095825195
# Computing the SD overlaps for step 48
# Done with computing the SD overlap of step 48. Elapsed time 0.029608488082885742
# Computing the SD overlaps for step 49
# Done with computing the SD overlap of step 49. Elapsed time 0.02891230583190918
# Computing the SD overlaps for step 50
# Done with computing the SD overlap of step 50. Elapsed time 0.037096500396728516
# Computing the SD overlaps for step 51
# Done with computing the SD overlap of step 51. Elapsed time 0.033258676528930664
# Computing the SD overlaps for step 52
# Done with computing the SD overlap of step 52. Elapsed time 0.030606508255004883
# Computing the SD overlaps for step 53
# Done with computing the SD overlap of step 53. Elapsed time 0.029459476470947266
# Computing the SD overlaps for step 54
# Done with computing the SD overlap of step 54. Elapsed time 0.028331995010375977
# Computing the SD overlaps for step 55
# Done with computing the SD overlap of step 55. Elapsed time 0.02844715118408203
# Computing the SD overlaps for step 56
# Done with computing the SD overlap of step 56. Elapsed time 0.028566360473632812
# Computing the SD overlaps for step 57
# Done with computing the SD overlap of step 57. Elapsed time 0.03686857223510742
# Computing the SD overlaps for step 58
# Done with computing the SD overlap of step 58. Elapsed time 0.036322593688964844
# Computing the SD overlaps for step 59
# Done with computing the SD overlap of step 59. Elapsed time 0.02914118766784668
# Computing the SD overlaps for step 60
# Done with computing the SD overlap of step 60. Elapsed time 0.030457735061645508
# Computing the SD overlaps for step 61
# Done with computing the SD overlap of step 61. Elapsed time 0.02824711799621582
# Computing the SD overlaps for step 62
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_100074/3801756430.py in <module>
#      22          }
#      23
# ---> 24 step3.run_step3_sd_nacs_libint(params_mb_sd)
#
# ~/work/libra-env/libra-local/_build/src/libra_py/workflows/nbra/step3.py in run_step3_sd_nacs_libint(params)
#    2455         St_sds = []
#    2456         for variable in var_pool:
# -> 2457             St_sd = compute_sd_overlaps_in_parallel(variable[0],variable[1])
#    2458             St_sds.append(St_sd)
#    2459
#
# ~/work/libra-env/libra-local/_build/src/libra_py/workflows/nbra/step3.py in compute_sd_overlaps_in_parallel(step, params)
#    2652                                            sd_states_reindexed_sorted[step], s_ks_1, use_minimal=False, use_mo_approach=True).real()
#    2653     s_sd_2 = mapping.ovlp_mat_arb(sd_states_reindexed_sorted[step+1],
# -> 2654                                            sd_states_reindexed_sorted[step+1], s_ks_2,use_minimal=False, use_mo_approach=True).real()
#    2655     st_sd = mapping.ovlp_mat_arb(sd_states_reindexed_sorted[step],
#    2656                                           sd_states_reindexed_sorted[step+1], st_ks, use_minimal=False, use_mo_approach=True).real()
#
# ~/work/libra-env/libra-local/_build/src/libra_py/workflows/nbra/mapping.py in ovlp_mat_arb(SD1, SD2, S, use_minimal, use_mo_approach, user_notation)
#     479             val = 0.0
#     480             if use_mo_approach==True:
# --> 481                 val = ovlp_arb_mo(SD1[n], SD2[m], S, user_notation)
#     482             else:
#     483                 val = ovlp_arb(SD1[n], SD2[m], S, use_minimal, user_notation)
#
# ~/work/libra-env/libra-local/_build/src/libra_py/workflows/nbra/mapping.py in ovlp_arb_mo(SD1, SD2, S, user_notation)
#     406     # Converting the SDs provided by the user into the internal format to be read by Libra
#     407     sd1 = sd2indx(SD1,nbasis, False, user_notation)
# --> 408     sd2 = sd2indx(SD2,nbasis, False, user_notation)
#     409
#     410     res = delta(Py2Cpp_int(sd1), Py2Cpp_int(sd2))
#
# ~/work/libra-env/libra-local/_build/src/libra_py/workflows/nbra/mapping.py in sd2indx(inp, nbasis, do_sort, user_notation)
#      97         # alpha
#      98         if inp[i] > 0:
# ---> 99             spat.append( inp[i] - 1 )
#     100
#     101         # beta
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Plot results <a name="plot_res"></a>
# [Back to TOC](#toc)
#
# ### 4.1. Energy vs time <a name="ene_time"></a>
#
# Here, we will plot the energies of single-particle and many-body excitation bases.

# %%
# Kohn-Sham BASIS PLOTS
#
# ACTIVE SPACE: HOMO-4; LUMO+4 (alpha has 1 unpaired electron)


# %matplotlib notebook
params = {"path_to_energy_files": "res-ks-DFT", "dt": 1.0, 
          "prefix": "E_", "suffix": "", "istep": 100, "fstep": 298}

titles = ['SP basis', 'MB basis']
plt.figure()
for c, basis in enumerate(['ks']):
    plt.subplot(1,2,1)
    params.update({"prefix": F"E_{basis}_"})
    md_time, energies = CP2K_methods.extract_energies_sparse(params)
    energies = energies #* units.au2ev
    plt.title('beta states')
    plt.ylabel('Orbital energy, au')
    plt.xlabel('Time, fs')
    
    for i in range(int(energies.shape[1]/2), energies.shape[1]):
        #if i==0: continue
        #plt.plot(md_time, energies[:,i]-energies[:,0],label=i) # sd
        plt.plot(md_time, energies[:,i],label=i) # ks
    plt.legend()
    plt.subplot(1,2,2)
    plt.title('alpha states')
    for i in range(int(energies.shape[1]/2)):
        #if i == 0: continue
        plt.plot(md_time, energies[:,i],label=i)
    

    plt.ylabel('Orbital energy, au')
    plt.xlabel('Time, fs')
    #plt.ylim(0, 0.5)
    plt.legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# SLATTER-DETERMINANT BASIS PLOTS
#
# ACTIVE SPACE: HOMO-4; LUMO+4 (alpha has 1 unpaired electron)


# %matplotlib notebook
params = {"path_to_energy_files": "res-mb-sd-DFT", "dt": 1.0, 
          "prefix": "E_", "suffix": "_re", "istep": 100, "fstep": 298}

titles = ['SP basis', 'MB basis']
plt.figure()
for c, basis in enumerate(['sd']):
    plt.subplot(1,1,1)
    params.update({"prefix": F"Hvib_{basis}_"})
    md_time, energies = CP2K_methods.extract_energies_sparse(params)
    #print(energies)
    energies = energies * units.au2ev
    #print(energies.shape[1])
    #plt.title('alpha states')
    for i in range(energies.shape[1]):
        if i in range(13): continue
        if i > 17 : continue
        #if i ==13: plt.plot(md_time, energies[:,i]-energies[:,0],label=i)
        plt.plot(md_time, energies[:,i]-energies[:,0], label=i) # sd
        #plt.plot(md_time, energies[:,i],label=i) # ks
    #plt.subplot(1,2,2)
    #plt.title('beta')
    #for i in range(int(energies.shape[1]/2), energies.shape[1]):
    #    if i == 0:
    #        continue
    #    plt.plot(md_time, energies[:,i]-energies[:,0],label=i)
    

    plt.ylabel('Excitation energy, au')
    plt.xlabel('Time, fs')
    plt.legend()
    #plt.ylim(0, 0.5)
    #plt.legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 4.2. Average partial density of states <a name="ave_pdos"></a>
# [Back to TOC](#toc)
#
# In this section, we will plot the average partial density of states (pDOS) over the MD trajectory. There are two ways to take the average of the pDOS:
#
# 1- Average all the pDOS files and then convolve the average pDOS for each element.
# 2- Convolve the pDOS files and then take the average for each element.
#
# We choose the first one due to two reasons. First, the computational cost is much lower and we only need one convolution. Second is that averaging over the grid points (using the method 2) is dependent on the number of grid points we use for convolution which again adds to the complexity of the procedure.
#
# Here, we will use normalized Gaussian function for weighting the pDOS values and summing them.
#
# $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}\exp(-\frac{(x-\mu)^2}{2\sigma^2})$$
#
# This function is defined in the `CP2K_methods.gaussian_function`.
#
# Now, we plot the pDOS for all of the angular momentum components of each atom. This is done by using the `orbital_cols`. In fact, the `orbital_cols` is related to `orbitals`. For example, for `s` orbital, we consider the 3rd index and for `p` orbital, we sum the columns from 4 to 6 (`range(4,7)`). Here we want to show how the code works and how the you can modify that based on your project. In the next section, we will show the pDOS only for atoms and sum all the components in each row of the pdos file. Other parameters are as follows:
#
# `atoms`: The atoms names and numbers as appear in the `pdos` files which will be used in convolution, labeling and plotting. The atoms order should be exactly the same as appear in the `.pdos` files. For example, the `*k1*.pdos` files contain the pDOS data for `Ti` atom and `*k2*.pdos` files contain the data for the `O` atom. Therefore, we set `"atoms": [[1,2] , ['Ti', 'O']]`.
#
# `npoints`: The number of grid points for making the Gaussian functions. Note that, this value should be more than the number of states in the `.pdos` files.
#
# `sigma`: The standard deviation in eV.
#
# `shift`: This value shifts the minimum and maximum energy found in the `pdos_ave` and will extend the boundaries from both sides by `shift`eV.
#
# Finally, we will plot the total density of states. We manually set the HOMO energy level to zero.

# %%
# %matplotlib notebook
params = {"path_to_all_pdos": '../../7_step2_cp2k/1_DFT/2_hpc/1_example_TiO2/all_pdosfiles', "atoms": [[1,2] , ['Ti', 'O']],
          "orbitals_cols": [[3], range(4,7), range(7,12), range(12,19)], "orbitals":  ['s','p','d','f'],
          "npoints": 4000, "sigma": 0.05, "shift": 2.0}

ave_energy_grid, homo_energy, ave_pdos_convolved, pdos_labels, ave_pdos_convolved_total = CP2K_methods.pdos(params)
for i in range(len(pdos_labels)):
    pdos_label = pdos_labels[i]
    plt.plot(ave_energy_grid-homo_energy, ave_pdos_convolved[i], label=pdos_label)
plt.plot(ave_energy_grid-homo_energy, ave_pdos_convolved_total, color='black', label='Total')
plt.legend()
plt.xlim(-4,4)
plt.ylabel('pDOS, 1/eV')
plt.xlabel('Energy, eV')
plt.title('TiO$_2$, 300 K')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_88120/3558496721.py in <module>
#       4           "npoints": 4000, "sigma": 0.05, "shift": 2.0}
#       5
# ----> 6 ave_energy_grid, homo_energy, ave_pdos_convolved, pdos_labels, ave_pdos_convolved_total = CP2K_methods.pdos(params)
#       7 for i in range(len(pdos_labels)):
#       8     pdos_label = pdos_labels[i]
#
# ~/work/libra-env/libra-local/_build/src/libra_py/packages/cp2k/methods.py in pdos(params)
#    1728         # Finding all the pdos files
#    1729         pdos_files = glob.glob(path_to_all_pdos+F'/*k{i}*.pdos')
# -> 1730         pdos_ave = np.zeros(np.loadtxt(pdos_files[0]).shape)
#    1731         cnt = len(pdos_files)
#    1732         for c2, pdos_file in enumerate(pdos_files):
#
# IndexError: list index out of range

# %% [markdown]
# ### 4.3. NAC map <a name="nac_map"></a>
# [Back to TOC](#toc)
#
# One way of visualizing the NAC values is to plot the average NAC matrix using `plt.imshow`.

# %%
# %matplotlib notebook
plt.figure()
titles = ['SP','MB']
for c1, basis in enumerate(['sd']):
    plt.subplot(1, 1, 1)
    nac_files = glob.glob(F'res-mb-sd-DFT/Hvib_{basis}*im*')
    for c2, nac_file in enumerate(nac_files):
        nac_mat = sp.load_npz(nac_file).todense().real
        if c2==0:
            nac_ave = np.zeros(nac_mat.shape)
        nac_ave += np.abs(nac_mat)
    nac_ave *= 1000*units.au2ev/c2
    nstates = nac_ave.shape[0]/2
    plt.imshow(np.flipud(nac_ave), cmap='hot', extent=(0,nstates,0,nstates))#, vmin=0, vmax=100)
    plt.xlabel('State index')
    plt.ylabel('State index')
    colorbar = plt.colorbar(shrink=0.50)
    colorbar.ax.set_title('meV')
    plt.clim(vmin=0, vmax=15)
    plt.title(F'{titles[c1]} NACs')
    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 4.4. NAC distribution <a name="nac_dist"></a>
# [Back to TOC](#toc)
#
# Another intuitive way to visualize the NACs is to plot the distribution of the NACs. Here we plot them for SP and MB excited states. A smoother distribution plot is obtained if more steps are involved.
#
# `data_stat.cmat_distrib` is used for computing the distribution of the NAC magnitudes within the range of $0$ to $50$ meV.

# %%
help(data_stat.cmat_distrib)
# Out:
# Help on function cmat_distrib in module libra_py.data_stat:
#
# cmat_distrib(X, i, j, component, xmin, xmax, dx)
#     Computes the distribution of the matrix element values in the list of CMATRIX(N,N) objects
#
#     Args:
#         X ( list of CMATRIX(N,N) objects ): the data to be analyzed
#         i ( int ): row index of the matrix element to analyze
#         j ( int ): column index of the matrix element to analyze
#         component ( int = 0 or 1 ): determines whether to analyze the real (0) or imaginary (1)
#             component of the data series
#         xmin ( double ): the minimal value of the bin support
#         xmax ( double ): the maximal value of the bin support
#         dx ( double ): the value of the bin support grid spacing
#
#     Returns:
#         tuple: ( bin_support, dens, cum ), where:
#
#             * bin_support ( list of doubles ): the range of values the distribution is computed for
#             * dens ( list of doubles ): the probability density
#             * cum ( list of doubles ): the cumulative distribution function

# %%
# %matplotlib notebook

for basis in ['sd']:
    nac = []
    nac_files = glob.glob(F'res-mb-sd-DFT/Hvib_{basis}*im*')
    for nac_file in nac_files:
        hvib = sp.load_npz(nac_file)
        hvib_dense = hvib.todense().real
        for i in range(hvib.shape[0]):
            for j in range(hvib.shape[0]):
                if j != i:
                    nac_ij = np.abs(hvib_dense[i,j])* 1000.0 * units.au2ev
                    x_mb = MATRIX(1,1)
                    x_mb.set(0, 0, nac_ij )
                    nac.append( x_mb )
    bin_supp, dens, cum = data_stat.cmat_distrib( nac, 0, 0, 0, 0, 50, 0.1)
    plt.plot( bin_supp, dens, label=basis)
plt.xlabel('|NAC|, meV')
plt.ylabel('PD, 1/meV')
plt.title('NAC distribution, SP vs MB')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
# plt.savefig('nac_dist_1.jpg', dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 4.5. Influence spectrum <a name="inf_spec"></a>
# [Back to TOC](#toc)
#
#
# In order to compute the influence spectrum for the energy gap fluctuations between two states, `i` and `j`. The parameters that need to be passed to the function `influence_spectrum.recipe1` are as follows:
#
# `data`: A list of `MATRIX(ndof, 1)` objects i.e. a sequence of real-valued ndof-dimensional vectors
#
# `dt`: Time step in fs units
#
# `wspan`: The window of frequencies for the Fourier transform with units cm$^{-1}$
#
# `dw`: The grid points spacing in the frequency domain with units of cm$^{-1}$
#
# `do_output`: Whether we print out the data the results into files
#
# `acf_filename`: The name of the file where to print the ACF
#
# `spectrum_filename`: The name of the file where to print the spectrum
#
# `do_center`: A flag controlling whether to center data (=`True`) or not (=`False`). Centering means we subtract the average value (over all the data points) from all the data points - this way, we convert values into their fluctuations
#
# `acf_type`: selector of the convention to to compute ACF:
# ```
#    * 0 : the chemist convention,  (1/(N-h)) Sum_{t=1,N-h} (Y[t]*Y[t+h]) [ default ]
#    * 1 : the statistician convention, (1/N) Sum_{t=1,N-h} (Y[t]*Y[t+h])
# ```
#
# `data_type`: What is the format of the data?
# ```
#         * 0 : list of MATRIX(ndof, 1) [ default ]
#         * 1 : list of VECTOR
# ```
#
# The `recipe1` function returns a tuple of (T, norm_acf, raw_acf, W, J, J2), where:
#
# `T`: List with time axis in `fs` units
#
# `norm_acf`: List with normalized ACF
#
# `raw_acf`: List with un-normalized ACF
#
# `W`: List with frequencies axis with units $cm^{-1}$
#
# `J`: List with amplitudes of Fourier transform
#
# `J2`: List with values of $(1/2\pi)|J|^2$
#
# Select two states of interest to compute the influence spectrum for their energy gap fluctuations. Here we comute that for the ground state, `i=0`, and the first excited state, `j=1` and then plot the spectrum.

# %%
# %matplotlib notebook
# For computing influence spectra
params_inf_cpec = {"dt": 1.0, "wspan": 4000.0, "dw": 1.0, "do_output": False,
          "do_center": True, "acf_type": 1, "data_type": 0}
# ==========
# Selecting the two states we want to compute the influence spectra for
i = 1; j = 2
# ========== Computing the autocorrelation function and the influence spectra
data_ij = []
for step in range(energies.shape[0]):
    x = MATRIX(1,1)
    if i<j:
        gap = energies[step,j]-energies[step,i]
    else:
        gap = energies[step,i]-energies[step,j]
    x.set(0,0, gap)
    data_ij.append(x)
Tij, ACFij, uACFij, Wij, Jij, J2ij = influence_spectrum.recipe1(data_ij, params_inf_cpec)

plt.plot(Wij, J2ij)
plt.xlabel('Frequency, cm$^{-1}$')
plt.ylabel('Intensity, a.u.')
plt.yticks([])
plt.title(F'Influence spectrum, states: {i},{j}')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
